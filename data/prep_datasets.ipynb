# %% [markdown]
# # Dataset 1: python-code-25k

# %%
from datasets import load_dataset
import pandas as pd
from helper_prep import get_prep_gemma

# %%
dataset = load_dataset("flytech/python-codes-25k")

instruction = dataset["train"]["instruction"]
print(f"{instruction[0]}\n")

output = dataset["train"]["output"]
print(f"{output[0]}\n")
# Out:
# Help me set up my daily to-do list!
#
# ```python
# tasks = []
# while True:
#     task = input('Enter a task or type 'done' to finish: ')
#     if task == 'done': break
#     tasks.append(task)
# print(f'Your to-do list for today: {tasks}')
# ```

# %%
python_25k = get_prep_gemma(instruction=instruction, output=output)
python_25k.head()
# Out:
# Len DataFrame: 49626
# Len DataFrame without Dups: 24813
#                                              instruction  \
# 21722  Teacher:In this task, you are given inputs i a...
# 21859  Detailed Instructions: In this task, you are g...
# 21887  In this task you will be given two lists of nu...
# 17244  Create a Python code generator for drawing a 3...
# 22073  I have huge data in a directory tree format li...
#
#                                                   output  \
# 21722  Sure, I can solve this task. The given integer...
# 21859  To accomplish this task, we will follow these ...
# 21887  To find the intersection between the two lists...
# 17244  ```python\nimport pyglet\n#cube window\nwindow...
# 22073  Yes, it is possible to write a script that can...
#
#                                               prep_gemma  text_len_gemma  \
# 21722  Instruction:\nTeacher:In this task, you are gi...             223
# 21859  Instruction:\nDetailed Instructions: In this t...             198
# 21887  Instruction:\nIn this task you will be given t...             281
# 17244  Instruction:\nCreate a Python code generator f...             142
# 22073  Instruction:\nI have huge data in a directory ...             300
#
#        token_len_gemma
# 21722              481
# 21859              479
# 21887              477
# 17244              476
# 22073              476

# %%
python_25k.to_csv("python_25k.csv", index=False)

# %%
df = pd.read_csv("python_25k.csv")
df.head()
# Out:
#                                          instruction  \
# 0  Teacher:In this task, you are given inputs i a...
# 1  Detailed Instructions: In this task, you are g...
# 2  In this task you will be given two lists of nu...
# 3  Create a Python code generator for drawing a 3...
# 4  I have huge data in a directory tree format li...
#
#                                               output  \
# 0  Sure, I can solve this task. The given integer...
# 1  To accomplish this task, we will follow these ...
# 2  To find the intersection between the two lists...
# 3  ```python\nimport pyglet\n#cube window\nwindow...
# 4  Yes, it is possible to write a script that can...
#
#                                           prep_gemma  text_len_gemma  \
# 0  Instruction:\nTeacher:In this task, you are gi...             223
# 1  Instruction:\nDetailed Instructions: In this t...             198
# 2  Instruction:\nIn this task you will be given t...             281
# 3  Instruction:\nCreate a Python code generator f...             142
# 4  Instruction:\nI have huge data in a directory ...             300
#
#    token_len_gemma
# 0              481
# 1              479
# 2              477
# 3              476
# 4              476

# %% [markdown]
# # Dataset 2: python-code-dataset-500k

# %%
dataset_2 = load_dataset("jtatman/python-code-dataset-500k")

instruction_2 = dataset_2["train"]["instruction"]
print(f"{instruction_2[0]}\n")

output_2 = dataset_2["train"]["output"]
print(output_2[0])
# Out:
# Create a nested loop to print every combination of numbers between 0-9, excluding any combination that contains the number 5. Additionally, exclude any combination that contains a repeating digit. Implement the solution without using any built-in functions or libraries to check for repeating digits.
#
# Here is an example of a nested loop in Python to print every combination of numbers between 0-9, excluding any combination that contains the number 5 or repeating digits:
#
# ```python
# for i in range(10):  # First digit
#     for j in range(10):  # Second digit
#         for k in range(10):  # Third digit
#             # Checking for the conditions
#             if i != 5 and j != 5 and k != 5 and i != j and i != k and j != k:
#                 print(i, j, k)
# ```
#
# This code will generate and print every combination of three digits between 0-9 that do not contain the number 5 and do not have any repeating digits.

# %%
python_500k = get_prep_gemma(instruction=instruction_2, output=output_2)
python_500k.head()
# Out:
# Len DataFrame: 559515
# Len DataFrame without Dups: 499472
#                                               instruction  \
# 132116  """Per-prefix data, mapping each prefix to a d...
# 129938  #  MINLP written by GAMS Convert at 08/20/20 0...
# 127865  # coding=utf-8\n# *** WARNING: this file was g...
# 130361  """\n \nU{Corelan<https://www.corelan.be>}\n\n...
# 126810  from pybindgen import Module, FileCodeSink, pa...
#
#                                                    output  \
# 132116  """Per-prefix data, mapping each prefix to a d...
# 129938  #  MINLP written by GAMS Convert at 08/20/20 0...
# 127865  # coding=utf-8\n# *** WARNING: this file was g...
# 130361  """\n \nU{Corelan<https://www.corelan.be>}\n\n...
# 126810  from pybindgen import Module, FileCodeSink, pa...
#
#                                                prep_gemma  text_len_gemma  \
# 132116  Instruction:\n"""Per-prefix data, mapping each...          101000
# 129938  Instruction:\n#  MINLP written by GAMS Convert...           94956
# 127865  Instruction:\n# coding=utf-8\n# *** WARNING: t...          169772
# 130361  Instruction:\n"""\n \nU{Corelan<https://www.co...          136622
# 126810  Instruction:\nfrom pybindgen import Module, Fi...           61352
#
#         token_len_gemma
# 132116          1272562
# 129938           459870
# 127865           446590
# 130361           415472
# 126810           326676

# %%
python_500k = python_500k.iloc[27000:]
python_500k.to_csv("python_500k.csv", index=False)

# %%
df = pd.read_csv("python_500k.csv")
df.head()
# Out:
#                                          instruction  \
# 0  Enhance the given code to add a search functio...
# 1  How would you explain what the following Pytho...
# 2  Make a summary of the following Python 3 code\...
# 3  Design a Python class to represent a 8 x 8 che...
# 4  Please write the following solution using Fort...
#
#                                               output  \
# 0  To enhance the code to add a search function, ...
# 1  Publish the project.\n\n    :param bool test: ...
# 2  Calculates improved shear correction factors f...
# 3  Here's an example implementation of a Python c...
# 4  ### Explanation\n The algorithm iterates throu...
#
#                                           prep_gemma  text_len_gemma  \
# 0  Instruction:\nEnhance the given code to add a ...           499.0
# 1  Instruction:\nHow would you explain what the f...           322.0
# 2  Instruction:\nMake a summary of the following ...           254.0
# 3  Instruction:\nDesign a Python class to represe...           478.0
# 4  Instruction:\nPlease write the following solut...           538.0
#
#    token_len_gemma
# 0           1024.0
# 1           1024.0
# 2           1024.0
# 3           1024.0
# 4           1024.0

# %% [markdown]
# # Dataset 3: Machine Learning Questions

# %%
dataset_3 = load_dataset("mjphayes/machine_learning_questions")

# %%
question = dataset_3["train"]["question"]
question_test = dataset_3["test"]["question"]

answer = dataset_3["train"]["answer"]
answer_test = dataset_3["test"]["answer"]

# %%
instruction_3 = question + question_test
print(f"{instruction_3[0]}\n")

output_3 = answer + answer_test
print(output_3[0])
# Out:
# A researcher has created a small simulation in MATLAB and we want to make it accessible to others. My plan is to take the simulation, clean up a few things and turn it into a set of functions. Then I plan to compile it into a C library and use SWIG to create a Python wrapper. At that point, I should be able to call the simulation from a small Django app. At least I hope so.
# Do I have the right plan? Has anyone else done something similar? Can you let me know if there are any serious pitfalls that I'm not aware of at the moment?
#
# One thing to remember is that the Matlab compiler does not actually compile the Matlab code into native machine instructions.  It simply wraps it into a standalone executable or a library with its own runtime engine that runs it.  You would be able to run your code without Matlab installed, and you would be able to interface it with other languages, but it will still be interpreted Matlab code, so there would be no speedup.

# %%
ml_questions = get_prep_gemma(instruction=instruction_3, output=output_3)
ml_questions.head()
# Out:
# Len DataFrame: 636
# Len DataFrame without Dups: 636
#                                            instruction  \
# 311  What is an example of how to derive a non-triv...
# 343  How can multiple solutions to a system of equa...
# 333  What is the outcome when you express the third...
# 505  What is the relationship between columns of a ...
# 314  Can you describe the thought process behind ge...
#
#                                                 output  \
# 311  An example of how to derive a non-trivial vers...
# 343  Multiple solutions to a system of equations ca...
# 333  When expressing the third and fourth columns o...
# 505  The relationship between columns of a matrix a...
# 314  The thought process behind generating non-triv...
#
#                                             prep_gemma  text_len_gemma  \
# 311  Instruction:\nWhat is an example of how to der...             113
# 343  Instruction:\nHow can multiple solutions to a ...              97
# 333  Instruction:\nWhat is the outcome when you exp...             102
# 505  Instruction:\nWhat is the relationship between...              93
# 314  Instruction:\nCan you describe the thought pro...              86
#
#      token_len_gemma
# 311              145
# 343              124
# 333              121
# 505              104
# 314              102

# %%
ml_questions.to_csv("ml_questions.csv", index=False)

# %%
df = pd.read_csv("ml_questions.csv")
df.head()
# Out:
#                                          instruction  \
# 0  What is an example of how to derive a non-triv...
# 1  How can multiple solutions to a system of equa...
# 2  What is the outcome when you express the third...
# 3  What is the relationship between columns of a ...
# 4  Can you describe the thought process behind ge...
#
#                                               output  \
# 0  An example of how to derive a non-trivial vers...
# 1  Multiple solutions to a system of equations ca...
# 2  When expressing the third and fourth columns o...
# 3  The relationship between columns of a matrix a...
# 4  The thought process behind generating non-triv...
#
#                                           prep_gemma  text_len_gemma  \
# 0  Instruction:\nWhat is an example of how to der...             113
# 1  Instruction:\nHow can multiple solutions to a ...              97
# 2  Instruction:\nWhat is the outcome when you exp...             102
# 3  Instruction:\nWhat is the relationship between...              93
# 4  Instruction:\nCan you describe the thought pro...              86
#
#    token_len_gemma
# 0              145
# 1              124
# 2              121
# 3              104
# 4              102

# %% [markdown]
# # Dataset 4: QA Python, Data Science, Machine Learning

# %%
dataset_4 = load_dataset("RazinAleks/SO-Python_QA-Data_Science_and_Machine_Learning_class")
# Out:
# Repo card metadata block was not found. Setting CardData to empty.

# %%
question_2 = dataset_4["train"]["Question"]
question_test_2 = dataset_4["test"]["Question"]
question_val_2 = dataset_4["validation"]["Question"]

answer_2 = dataset_4["train"]["Answer"]
answer_test_2 = dataset_4["test"]["Answer"]
answer_val_2 = dataset_4["validation"]["Answer"]

# %%
instruction_4 = question_2 + question_test_2 + question_val_2
print(f"{instruction_4[24]}\n")

output_4 = answer_2 + answer_test_2 + answer_val_2
print(output_4[24])
# Out:
# What's the easiest way to shuffle an array with python?
#
# In addition to the previous replies, I would like to introduce another function.
# numpy.random.shuffle as well as random.shuffle perform in-place shuffling. However, if you want to return a shuffled array numpy.random.permutation is the function to use.

# %%
qa_python_ds_ml = get_prep_gemma(instruction=instruction_4, output=output_4)
qa_python_ds_ml.head()
# Out:
# Len DataFrame: 8889
# Len DataFrame without Dups: 8889
#                                             instruction  \
# 8187  Since today tensorflow seems to output the ent...
# 2711  I'm currently trying to train the MLPClassifie...
# 8854  I received an excel file containing some JSON ...
# 6915  I am trying to install pytorch-geometric for a...
# 3689  I am still getting this error: An error occurr...
#
#                                                  output  \
# 8187  Figured out why I get this output all of a sud...
# 2711  Your data does not make any sense from scikit-...
# 8854  I took the raw data the one you mentioned abov...
# 6915  I've found a combination of packages that work...
# 3689  The problem is that you have two Python versio...
#
#                                              prep_gemma  text_len_gemma  \
# 8187  Instruction:\nSince today tensorflow seems to ...            1059
# 2711  Instruction:\nI'm currently trying to train th...             634
# 8854  Instruction:\nI received an excel file contain...             428
# 6915  Instruction:\nI am trying to install pytorch-g...             934
# 3689  Instruction:\nI am still getting this error: A...             681
#
#       token_len_gemma
# 8187            10920
# 2711             5056
# 8854             4938
# 6915             4877
# 3689             3397

# %%
qa_python_ds_ml = qa_python_ds_ml.iloc[82:]
qa_python_ds_ml.head()
# Out:
#                                             instruction  \
# 1597  I wish to compare around 1000 lists of varying...
# 4651  When running keras model inside Jupyter notebo...
# 488   Background\nI am working on a fairly computati...
# 4518  I was writing a code to read a csv file using ...
# 3214  Tagged this as Python because is the most pseu...
#
#                                                  output  \
# 1597  Nothing is going to be superfast, and there's ...
# 4651  After a few tests I found that the error is re...
# 488   Two ideas:\n\nUse numpy arrays to represent ve...
# 4518  The difference pops up when working with a dat...
# 3214  Let's try the following:\nSuppose we have an m...
#
#                                              prep_gemma  text_len_gemma  \
# 1597  Instruction:\nI wish to compare around 1000 li...             785
# 4651  Instruction:\nWhen running keras model inside ...             344
# 488   Instruction:\nBackground\nI am working on a fa...             783
# 4518  Instruction:\nI was writing a code to read a c...             311
# 3214  Instruction:\nTagged this as Python because is...             664
#
#       token_len_gemma
# 1597             1018
# 4651              997
# 488               996
# 4518              989
# 3214              987

# %%
qa_python_ds_ml.to_csv("qa_python_ds_ml.csv", index=False)

# %%
print(qa_python_ds_ml["prep_gemma"][0])
# Out:
# Instruction:
# A researcher has created a small simulation in MATLAB and we want to make it accessible to others. My plan is to take the simulation, clean up a few things and turn it into a set of functions. Then I plan to compile it into a C library and use SWIG to create a Python wrapper. At that point, I should be able to call the simulation from a small Django app. At least I hope so.
# Do I have the right plan? Has anyone else done something similar? Can you let me know if there are any serious pitfalls that I'm not aware of at the moment?
#
# Response:
# One thing to remember is that the Matlab compiler does not actually compile the Matlab code into native machine instructions.  It simply wraps it into a standalone executable or a library with its own runtime engine that runs it.  You would be able to run your code without Matlab installed, and you would be able to interface it with other languages, but it will still be interpreted Matlab code, so there would be no speedup.
